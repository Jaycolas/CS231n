# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
  """
  Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
  it for the linear classifier. These are the same steps as we used for the
  SVM, but condensed to a single function.  
  """
  # Load the raw CIFAR-10 data
  cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
  X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
  
  # subsample the data
  mask = range(num_training, num_training + num_validation)
  X_val = X_train[mask]
  y_val = y_train[mask]
  mask = range(num_training)
  X_train = X_train[mask]
  y_train = y_train[mask]
  mask = range(num_test)
  X_test = X_test[mask]
  y_test = y_test[mask]
  mask = np.random.choice(num_training, num_dev, replace=False)
  X_dev = X_train[mask]
  y_dev = y_train[mask]
  
  # Preprocessing: reshape the image data into rows
  X_train = np.reshape(X_train, (X_train.shape[0], -1))
  X_val = np.reshape(X_val, (X_val.shape[0], -1))
  X_test = np.reshape(X_test, (X_test.shape[0], -1))
  X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
  
  # Normalize the data: subtract the mean image
  mean_image = np.mean(X_train, axis = 0)
  X_train -= mean_image
  X_val -= mean_image
  X_test -= mean_image
  X_dev -= mean_image
  
  # add bias dimension and transform into columns
  X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
  X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
  X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
  X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
  
  return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print 'Train data shape: ', X_train.shape
print 'Train labels shape: ', y_train.shape
print 'Validation data shape: ', X_val.shape
print 'Validation labels shape: ', y_val.shape
print 'Test data shape: ', X_test.shape
print 'Test labels shape: ', y_test.shape
print 'dev data shape: ', X_dev.shape
print 'dev labels shape: ', y_dev.shape
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print 'loss: %f' % loss
print 'sanity check: %f' % (-np.log(0.1))
# Out:
# loss: 2.375167
# sanity check: 2.302585

# %% [markdown]
# ## Inline Question 1:
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# **Your answer:** *Fill this in*
# Because we assume the 10 categories of pictures are distributed randomly, so roughly they should be having equal probability.

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 1e2)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 1e2)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: 0.413925 analytic: 0.413925, relative error: 1.318012e-08
# numerical: -1.548447 analytic: -1.548447, relative error: 2.944041e-08
# numerical: -1.681626 analytic: -1.681626, relative error: 1.707924e-08
# numerical: -0.357530 analytic: -0.357530, relative error: 1.028554e-08
# numerical: -2.176036 analytic: -2.176036, relative error: 3.007540e-08
# numerical: -1.030219 analytic: -1.030219, relative error: 2.506556e-08
# numerical: 2.161935 analytic: 2.161935, relative error: 1.142559e-08
# numerical: 1.785532 analytic: 1.785532, relative error: 1.026067e-08
# numerical: 0.063493 analytic: 0.063492, relative error: 4.993853e-07
# numerical: 2.888980 analytic: 2.888980, relative error: 1.262500e-08
# numerical: 1.828219 analytic: 1.828219, relative error: 7.997205e-09
# numerical: -0.162832 analytic: -0.162832, relative error: 1.714174e-07
# numerical: -2.657773 analytic: -2.657773, relative error: 1.695336e-09
# numerical: -2.973754 analytic: -2.973754, relative error: 5.112754e-09
# numerical: -3.068752 analytic: -3.068752, relative error: 1.896272e-09
# numerical: 0.868603 analytic: 0.868603, relative error: 5.268070e-08
# numerical: -0.462368 analytic: -0.462368, relative error: 3.316444e-08
# numerical: 1.248925 analytic: 1.248924, relative error: 3.198309e-08
# numerical: -1.029110 analytic: -1.029110, relative error: 4.783453e-09
# numerical: 0.120201 analytic: 0.120201, relative error: 2.402046e-08

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.00001)
toc = time.time()
print 'naive loss: %e computed in %fs' % (loss_naive, toc - tic)

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.00001)
toc = time.time()
print 'vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic)

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print 'Loss difference: %f' % np.abs(loss_naive - loss_vectorized)
print 'Gradient difference: %f' % grad_difference
# Out:
# naive loss: 2.375167e+00 computed in 0.152269s
# vectorized loss: 2.375167e+00 computed in 0.005149s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates = [1e-7,3e-7, 5e-7,7e-7,8e-7,1e-6]
regularization_strengths = [5e4, 4e4,7e4, 8e4,1e5]

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
for alpha in learning_rates:
    for r in regularization_strengths:
        sftmax = Softmax()
        loss_hist = sftmax.train(X_train, y_train, learning_rate=alpha, reg=r,
                      num_iters=800, verbose=True)
        y_train_pred = sftmax.predict(X_train)
        y_val_pred = sftmax.predict(X_val)
        train_accuracy = np.mean(y_train == y_train_pred)
        val_accuracy = np.mean(y_val == y_val_pred)
        results[(alpha,r)]=(train_accuracy, val_accuracy)
        if val_accuracy > best_val:
            best_val = val_accuracy
            best_softmax = sftmax
            best_learning_rate = alpha
            best_reg_strength = r
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print 'lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy)
    
print 'best validation accuracy achieved during cross-validation: %f' % best_val
# Out:
# iteration 0 / 800: loss 777.758511
# iteration 100 / 800: loss 284.843614
# iteration 200 / 800: loss 105.443343
# iteration 300 / 800: loss 40.007750
# iteration 400 / 800: loss 15.997664
# iteration 500 / 800: loss 7.243763
# iteration 600 / 800: loss 3.872295
# iteration 700 / 800: loss 2.729547
# iteration 0 / 800: loss 618.681187
# iteration 100 / 800: loss 277.710022
# iteration 200 / 800: loss 125.136751
# iteration 300 / 800: loss 57.146028
# iteration 400 / 800: loss 26.722748
# iteration 500 / 800: loss 13.037229
# iteration 600 / 800: loss 7.052255
# iteration 700 / 800: loss 4.279996
# iteration 0 / 800: loss 1083.865650
# iteration 100 / 800: loss 266.414061
# iteration 200 / 800: loss 66.782733
# iteration 300 / 800: loss 17.943412
# iteration 400 / 800: loss 5.998187
# iteration 500 / 800: loss 3.036002
# iteration 600 / 800: loss 2.333928
# iteration 700 / 800: loss 2.231383
# iteration 0 / 800: loss 1228.721122
# iteration 100 / 800: loss 246.958017
# iteration 200 / 800: loss 51.033309
# iteration 300 / 800: loss 11.901775
# iteration 400 / 800: loss 4.041901
# iteration 500 / 800: loss 2.468192
# iteration 600 / 800: loss 2.195434
# iteration 700 / 800: loss 2.148260
# iteration 0 / 800: loss 1553.342875
# iteration 100 / 800: loss 208.907871
# iteration 200 / 800: loss 29.775472
# iteration 300 / 800: loss 5.880800
# iteration 400 / 800: loss 2.596420
# iteration 500 / 800: loss 2.251511
# iteration 600 / 800: loss 2.182598
# iteration 700 / 800: loss 2.154116
# iteration 0 / 800: loss 774.860365
# iteration 100 / 800: loss 39.261615
# iteration 200 / 800: loss 3.888311
# iteration 300 / 800: loss 2.118350
# iteration 400 / 800: loss 2.102371
# iteration 500 / 800: loss 2.146796
# iteration 600 / 800: loss 2.138750
# iteration 700 / 800: loss 2.149781
# iteration 0 / 800: loss 616.941160
# iteration 100 / 800: loss 56.461759
# iteration 200 / 800: loss 6.875066
# iteration 300 / 800: loss 2.493059
# iteration 400 / 800: loss 2.066597
# iteration 500 / 800: loss 2.057053
# iteration 600 / 800: loss 2.022969
# iteration 700 / 800: loss 2.019983
# iteration 0 / 800: loss 1069.134753
# iteration 100 / 800: loss 17.261296
# iteration 200 / 800: loss 2.317894
# iteration 300 / 800: loss 2.086623
# iteration 400 / 800: loss 2.048805
# iteration 500 / 800: loss 2.150639
# iteration 600 / 800: loss 2.117163
# iteration 700 / 800: loss 2.109531
# iteration 0 / 800: loss 1217.429010
# iteration 100 / 800: loss 11.462968
# iteration 200 / 800: loss 2.183503
# iteration 300 / 800: loss 2.129443
# iteration 400 / 800: loss 2.123722
# iteration 500 / 800: loss 2.140247
# iteration 600 / 800: loss 2.121891
# iteration 700 / 800: loss 2.137709
# iteration 0 / 800: loss 1534.199844
# iteration 100 / 800: loss 5.562911
# iteration 200 / 800: loss 2.150936
# iteration 300 / 800: loss 2.135287
# iteration 400 / 800: loss 2.161642
# iteration 500 / 800: loss 2.163936
# iteration 600 / 800: loss 2.114998
# iteration 700 / 800: loss 2.127298
# iteration 0 / 800: loss 762.403508
# iteration 100 / 800: loss 6.841986
# iteration 200 / 800: loss 2.131240
# iteration 300 / 800: loss 2.132352
# iteration 400 / 800: loss 2.112670
# iteration 500 / 800: loss 2.129376
# iteration 600 / 800: loss 2.080892
# iteration 700 / 800: loss 2.086113
# iteration 0 / 800: loss 610.996610
# iteration 100 / 800: loss 12.636365
# iteration 200 / 800: loss 2.209941
# iteration 300 / 800: loss 2.081660
# iteration 400 / 800: loss 1.968459
# iteration 500 / 800: loss 2.061147
# iteration 600 / 800: loss 2.103826
# iteration 700 / 800: loss 2.115523
# iteration 0 / 800: loss 1062.461926
# iteration 100 / 800: loss 2.954662
# iteration 200 / 800: loss 2.093172
# iteration 300 / 800: loss 2.151951
# iteration 400 / 800: loss 2.192622
# iteration 500 / 800: loss 2.050710
# iteration 600 / 800: loss 2.128835
# iteration 700 / 800: loss 2.195525
# iteration 0 / 800: loss 1243.003932
# iteration 100 / 800: loss 2.497538
# iteration 200 / 800: loss 2.161746
# iteration 300 / 800: loss 2.110546
# iteration 400 / 800: loss 2.137356
# iteration 500 / 800: loss 2.128156
# iteration 600 / 800: loss 2.116401
# iteration 700 / 800: loss 2.157289
# iteration 0 / 800: loss 1543.057113
# iteration 100 / 800: loss 2.201394
# iteration 200 / 800: loss 2.135656
# iteration 300 / 800: loss 2.128264
# iteration 400 / 800: loss 2.143701
# iteration 500 / 800: loss 2.140992
# iteration 600 / 800: loss 2.163430
# iteration 700 / 800: loss 2.201597
# iteration 0 / 800: loss 769.242810
# iteration 100 / 800: loss 2.719276
# iteration 200 / 800: loss 2.066608
# iteration 300 / 800: loss 2.052605
# iteration 400 / 800: loss 2.114117
# iteration 500 / 800: loss 2.087560
# iteration 600 / 800: loss 2.077129
# iteration 700 / 800: loss 2.116526
# iteration 0 / 800: loss 625.037102
# iteration 100 / 800: loss 4.140246
# iteration 200 / 800: loss 2.071090
# iteration 300 / 800: loss 2.061416
# iteration 400 / 800: loss 2.061145
# iteration 500 / 800: loss 2.097865
# iteration 600 / 800: loss 2.067410
# iteration 700 / 800: loss 2.047456
# iteration 0 / 800: loss 1090.551305
# iteration 100 / 800: loss 2.198026
# iteration 200 / 800: loss 2.144701
# iteration 300 / 800: loss 2.171465
# iteration 400 / 800: loss 2.145150
# iteration 500 / 800: loss 2.103335
# iteration 600 / 800: loss 2.084397
# iteration 700 / 800: loss 2.109516
# iteration 0 / 800: loss 1243.117087
# iteration 100 / 800: loss 2.116535
# iteration 200 / 800: loss 2.169992
# iteration 300 / 800: loss 2.108628
# iteration 400 / 800: loss 2.070743
# iteration 500 / 800: loss 2.141075
# iteration 600 / 800: loss 2.133056
# iteration 700 / 800: loss 2.140480
# iteration 0 / 800: loss 1526.100673
# iteration 100 / 800: loss 2.172498
# iteration 200 / 800: loss 2.128840
# iteration 300 / 800: loss 2.172591
# iteration 400 / 800: loss 2.179326
# iteration 500 / 800: loss 2.145120
# iteration 600 / 800: loss 2.141109
# iteration 700 / 800: loss 2.176629
# iteration 0 / 800: loss 780.485026
# iteration 100 / 800: loss 2.345415
# iteration 200 / 800: loss 2.044600
# iteration 300 / 800: loss 2.110461
# iteration 400 / 800: loss 1.983625
# iteration 500 / 800: loss 2.125003
# iteration 600 / 800: loss 2.098301
# iteration 700 / 800: loss 2.073750
# iteration 0 / 800: loss 625.154745
# iteration 100 / 800: loss 2.987034
# iteration 200 / 800: loss 2.021704
# iteration 300 / 800: loss 2.122735
# iteration 400 / 800: loss 2.054020
# iteration 500 / 800: loss 2.062007
# iteration 600 / 800: loss 2.065452
# iteration 700 / 800: loss 2.084190
# iteration 0 / 800: loss 1071.896067
# iteration 100 / 800: loss 2.171159
# iteration 200 / 800: loss 2.107919
# iteration 300 / 800: loss 2.098145
# iteration 400 / 800: loss 2.163831
# iteration 500 / 800: loss 2.123559
# iteration 600 / 800: loss 2.147147
# iteration 700 / 800: loss 2.082051
# iteration 0 / 800: loss 1241.869324
# iteration 100 / 800: loss 2.142453
# iteration 200 / 800: loss 2.158106
# iteration 300 / 800: loss 2.188409
# iteration 400 / 800: loss 2.125275
# iteration 500 / 800: loss 2.139236
# iteration 600 / 800: loss 2.144683
# iteration 700 / 800: loss 2.122449
# iteration 0 / 800: loss 1543.902724
# iteration 100 / 800: loss 2.178512
# iteration 200 / 800: loss 2.141589
# iteration 300 / 800: loss 2.205719
# iteration 400 / 800: loss 2.150840
# iteration 500 / 800: loss 2.151782
# iteration 600 / 800: loss 2.127183
# iteration 700 / 800: loss 2.180490
# iteration 0 / 800: loss 777.944207
# iteration 100 / 800: loss 2.155087
# iteration 200 / 800: loss 2.201577
# iteration 300 / 800: loss 2.089331
# iteration 400 / 800: loss 2.148752
# iteration 500 / 800: loss 2.039553
# iteration 600 / 800: loss 2.088668
# iteration 700 / 800: loss 2.088939
# iteration 0 / 800: loss 623.641468
# iteration 100 / 800: loss 2.268299
# iteration 200 / 800: loss 2.098880
# iteration 300 / 800: loss 2.061009
# iteration 400 / 800: loss 2.110753
# iteration 500 / 800: loss 2.075298
# iteration 600 / 800: loss 2.031552
# iteration 700 / 800: loss 2.039073
# iteration 0 / 800: loss 1054.499416
# iteration 100 / 800: loss 2.152494
# iteration 200 / 800: loss 2.086858
# iteration 300 / 800: loss 2.087859
# iteration 400 / 800: loss 2.124131
# iteration 500 / 800: loss 2.080432
# iteration 600 / 800: loss 2.160893
# iteration 700 / 800: loss 2.134705
# iteration 0 / 800: loss 1245.642382
# iteration 100 / 800: loss 2.160931
# iteration 200 / 800: loss 2.184875
# iteration 300 / 800: loss 2.113312
# iteration 400 / 800: loss 2.131657
# iteration 500 / 800: loss 2.115056
# iteration 600 / 800: loss 2.181595
# iteration 700 / 800: loss 2.172144
# iteration 0 / 800: loss 1548.459691
# iteration 100 / 800: loss 2.149598
# iteration 200 / 800: loss 2.159627
# iteration 300 / 800: loss 2.176367
# iteration 400 / 800: loss 2.183421
# iteration 500 / 800: loss 2.149695
# iteration 600 / 800: loss 2.080644
# iteration 700 / 800: loss 2.159353
# lr 1.000000e-07 reg 4.000000e+04 train accuracy: 0.331776 val accuracy: 0.348000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.328306 val accuracy: 0.345000
# lr 1.000000e-07 reg 7.000000e+04 train accuracy: 0.320286 val accuracy: 0.336000
# lr 1.000000e-07 reg 8.000000e+04 train accuracy: 0.311551 val accuracy: 0.327000
# lr 1.000000e-07 reg 1.000000e+05 train accuracy: 0.310755 val accuracy: 0.322000
# lr 3.000000e-07 reg 4.000000e+04 train accuracy: 0.334265 val accuracy: 0.351000
# lr 3.000000e-07 reg 5.000000e+04 train accuracy: 0.328612 val accuracy: 0.346000
# lr 3.000000e-07 reg 7.000000e+04 train accuracy: 0.323714 val accuracy: 0.327000
# lr 3.000000e-07 reg 8.000000e+04 train accuracy: 0.316673 val accuracy: 0.338000
# lr 3.000000e-07 reg 1.000000e+05 train accuracy: 0.301939 val accuracy: 0.318000
# lr 5.000000e-07 reg 4.000000e+04 train accuracy: 0.331592 val accuracy: 0.354000
# lr 5.000000e-07 reg 5.000000e+04 train accuracy: 0.321163 val accuracy: 0.336000
# lr 5.000000e-07 reg 7.000000e+04 train accuracy: 0.313000 val accuracy: 0.331000
# lr 5.000000e-07 reg 8.000000e+04 train accuracy: 0.306694 val accuracy: 0.317000
# lr 5.000000e-07 reg 1.000000e+05 train accuracy: 0.300102 val accuracy: 0.302000
# lr 7.000000e-07 reg 4.000000e+04 train accuracy: 0.332959 val accuracy: 0.339000
# lr 7.000000e-07 reg 5.000000e+04 train accuracy: 0.329531 val accuracy: 0.329000
# lr 7.000000e-07 reg 7.000000e+04 train accuracy: 0.313571 val accuracy: 0.329000
# lr 7.000000e-07 reg 8.000000e+04 train accuracy: 0.300694 val accuracy: 0.312000
# lr 7.000000e-07 reg 1.000000e+05 train accuracy: 0.294571 val accuracy: 0.310000
# lr 8.000000e-07 reg 4.000000e+04 train accuracy: 0.325000 val accuracy: 0.343000
# lr 8.000000e-07 reg 5.000000e+04 train accuracy: 0.317286 val accuracy: 0.321000
# lr 8.000000e-07 reg 7.000000e+04 train accuracy: 0.317286 val accuracy: 0.342000
# lr 8.000000e-07 reg 8.000000e+04 train accuracy: 0.310000 val accuracy: 0.324000
# lr 8.000000e-07 reg 1.000000e+05 train accuracy: 0.282102 val accuracy: 0.294000
# lr 1.000000e-06 reg 4.000000e+04 train accuracy: 0.322163 val accuracy: 0.315000
# lr 1.000000e-06 reg 5.000000e+04 train accuracy: 0.326204 val accuracy: 0.357000
# lr 1.000000e-06 reg 7.000000e+04 train accuracy: 0.297551 val accuracy: 0.305000
# lr 1.000000e-06 reg 8.000000e+04 train accuracy: 0.312449 val accuracy: 0.329000
# lr 1.000000e-06 reg 1.000000e+05 train accuracy: 0.296796 val accuracy: 0.292000
# best validation accuracy achieved during cross-validation: 0.357000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print 'softmax on raw pixels final test set accuracy: %f' % (test_accuracy, )
# Out:
# softmax on raw pixels final test set accuracy: 0.354000

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in xrange(10):
  plt.subplot(2, 5, i + 1)
  
  # Rescale the weights to be between 0 and 255
  wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
  plt.imshow(wimg.astype('uint8'))
  plt.axis('off')
  plt.title(classes[i])
